# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from notebooks.imports import *

import scipy.io as sio
import h5py

import hdf5storage

# %% [markdown]
# ### Load Configs

# %%
from config import dir_config, main_config

raw_dir = Path(dir_config.data.raw)
processed_dir = Path(dir_config.data.processed)

# %% [markdown]
# ### Utils functions

# %%
def determine_choice(row):
    if row['is_valid']:
        if row['outcome']:
            return row['target']
        else:
            return 'left' if row['target'] == 'right' else 'right'
    else:
        return np.NaN

def get_prior_condition(df):
    valid_df = df[df['is_valid']].copy()  # Ensure valid_df is a copy to avoid SettingWithCopyWarning

    # Calculate trial counts and percentages for each condition within valid trials
    condition_counts = valid_df.groupby(['target', 'color']).size().reset_index(name='counts')
    total_counts = condition_counts.groupby('color')['counts'].transform('sum')
    condition_counts['percentage'] = (condition_counts['counts'] / total_counts) * 100

    # Filter conditions meeting the 60% criterion
    conditions_met = condition_counts[(condition_counts['percentage'] > 60)].copy()  # Make a copy to safely modify

    # Prepare the output based on conditions met
    if not conditions_met.empty:
        # Use .loc to modify 'condition' column safely
        conditions_met.loc[:, 'condition'] = conditions_met.apply(lambda x: 'gr' if x['target'] == "right" and x['color'] == "green"
                                                                else ('gl' if x['target'] == "left" and x['color'] == "green"
                                                                        else ('rr' if x['target'] == "right" and x['color'] == "red"
                                                                            else 'rl')), axis=1)
        return conditions_met[['condition', 'target', 'color']].values.tolist()[0]
    else:
        return ['eq', -1, -1]

# %% [markdown]
# ### Raw Data Column Description
# #### Codes
#     - 1001              Start trial
#     - 2500              Fixation point ON
#     - 2000              Targets appears (white choice cue for correct)
#     - 2009              Distractor appears (white choice cue for wrong)
#     - 4000:4001     Target (correct choice) is left (4000) or right (4001)
#     - 4100:4199     Difficulty levels or coherence levels (4100= easiest)
#     - 5000              Glass pattern appears
#     - 5500              Glass pattern disappears
#     - 5001              (invalid trial)	Failed to hold fixation
#     - 5004              (invalid trial)	Failed to hold target
#     - 5005              (invalid trial)	Anticipatory saccade
#     - 5006              Chose distractor (wrong choice)
#     - 5007              Failed to respond on time
#     - 5510              Correct choice
#     - 1503              The actual key press
#     - 6101:6102     Glass pattern color (6101: green)
# ##### Events (starting with one)
#     - 3rd column: GP orientation
#     - 4th column: % coherence {4100:100; 4101:35; 4102:13; 4103:0}
#     - 5th column: GP color
#     - 9th column: correct?
# ##### Time (starting with one)
#     - Reaction Time: 8th column - 7th column

# %% [markdown]
# ## Compiling data from all subjects

# %%
fragment_data_path = raw_dir / 'harvard_data' / 'pd'
assert fragment_data_path.exists(), f"Fragment data path {fragment_data_path} does not exist."

# Get folder names
folders = [f for f in fragment_data_path.iterdir() if f.is_dir()]
folders
# Out:
# [PosixPath('/mnt/pd-data/raw/harvard_data/pd/P8_on'),
#  PosixPath('/mnt/pd-data/raw/harvard_data/pd/P8_off'),
#  PosixPath('/mnt/pd-data/raw/harvard_data/pd/P5_off'),
#  PosixPath('/mnt/pd-data/raw/harvard_data/pd/P2_off'),
#  PosixPath('/mnt/pd-data/raw/harvard_data/pd/P5_on'),
#  PosixPath('/mnt/pd-data/raw/harvard_data/pd/P2_on')]

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import hdf5storage

def process_sessions(folders, raw_dir, should_save=False):
	for idx, folder in enumerate(folders):
		trial_path = folder / 'trial'
		files = sorted(trial_path.glob('*.mat'))

		if not files:
			print(f"No .mat files found in {trial_path}")
			continue

		session_data = {"event": [], "time": []}

		# Load and concatenate data
		for file in files:
			temp_data = hdf5storage.loadmat(file.as_posix())
			session_data["event"].append(temp_data['event'])
			session_data["time"].append(temp_data['time'])

		session_data["event"] = np.concatenate(session_data["event"])
		session_data["time"] = np.concatenate(session_data["time"])

		# Create DataFrame
		event = session_data['event']
		df = pd.DataFrame({
			'color': np.select([event[:, 4] == 6101, event[:, 4] == 6102], ['green', 'red'], default=np.NaN),
			'coherence': np.select(
				[event[:, 3] == 4100, event[:, 3] == 4101, event[:, 3] == 4102, event[:, 3] == 4103],
				[100, 35, 13, 0],
				default=np.NaN
			),
			'target': np.select([event[:, 2] == 4000, event[:, 2] == 4001], ['left', 'right'], default=np.NaN),
		})

		# Mark invalid trials
		invalid_trials = np.where(
			(event[:, 8] == 5007) | (event[:, 7] == 5005) | (event[:, 7] == 0) | (event[:, 7] == 5008)
		)[0]
		df['is_valid'] = True
		df.loc[invalid_trials, 'is_valid'] = False

		# Determine outcome
		df['outcome'] = np.nan
		df.loc[np.where(event[:, 8] == 5510)[0], 'outcome'] = 1
		df.loc[np.where(event[:, 7] == 5006)[0], 'outcome'] = 0

		# Determine choice
		df['choice'] = df.apply(determine_choice, axis=1)

		# Calculate reaction time
		df['reaction_time'] = session_data['time'][:, 7] - session_data['time'][:, 6]

		# Infer prior condition
		prior, _, _ = get_prior_condition(df)

		if should_save:
			# Generate save name
			parts = folder.name.split('_')
			if len(parts) < 2:
				print(f"Folder name {folder.name} does not follow expected format.")
				continue

			savename = f"H{parts[0][1:].capitalize()}_{parts[1].upper()}meds_{prior}"

			# Save .mat file
			save_path = raw_dir / 'harvard_data' / 'pd' / f"{savename}.mat"
			save_path.parent.mkdir(parents=True, exist_ok=True)

			hdf5storage.savemat(save_path.as_posix(), session_data, format='7.3')
			print(f"Saved: {save_path.name}")
		else:
			return df

# %%
fragment_data_path = raw_dir / 'harvard_data' / 'pd'
assert fragment_data_path.exists(), f"Fragment data path {fragment_data_path} does not exist."

# Get folder names
folders = [f for f in fragment_data_path.iterdir() if f.is_dir()]

# Now call the function
process_sessions(folders, raw_dir)
# Out:
#      color  coherence target  is_valid  outcome choice  reaction_time
# 0      red        0.0  right     False      NaN    NaN    1670.214164
# 1      red      100.0   left      True      1.0   left     992.601647
# 2    green      100.0   left      True      1.0   left     866.981356
# 3      red       35.0   left      True      1.0   left     970.516480
# 4    green       35.0   left      True      0.0  right    1349.344004
# 5    green       35.0   left      True      1.0   left     918.273553
# 6    green      100.0   left      True      1.0   left     922.652001
# 7      red       35.0   left      True      1.0   left    1002.155455
# 8      red        0.0   left      True      1.0   left     971.325036
# 9    green       13.0   left      True      0.0  right    1112.180283
# 10   green       13.0   left      True      0.0  right    1163.031722
# 11     red       35.0  right      True      0.0   left    1109.936041
# 12     red        0.0   left      True      1.0   left    1034.400635
# 13   green       13.0  right      True      1.0  right    1094.615283
# 14     red        0.0  right      True      0.0   left     965.651799
# 15     red       13.0  right      True      1.0  right    1327.297813
# 16   green       35.0  right      True      0.0   left    1384.494248
# 17     red       13.0   left      True      1.0   left    1305.920530
# 18   green        0.0   left      True      0.0  right    1032.575655
# 19     red       13.0   left      True      1.0   left     766.516465
# 20     red      100.0  right      True      1.0  right    1167.580753
# 21   green        0.0   left      True      0.0  right    1127.433409
# 22   green       35.0   left      True      1.0   left     794.056000
# 23   green        0.0   left     False      NaN    NaN    1609.786685
# 24     nan        NaN    nan     False      NaN    NaN       0.000000
# 25   green        0.0  right      True      1.0  right    1191.580137
# 26   green       13.0   left      True      0.0  right    1092.312233
# 27   green      100.0  right      True      1.0  right    1164.992898
# 28     red       35.0  right      True      0.0   left    1330.649347
# 29   green      100.0   left      True      1.0   left     857.718441
# 30     red      100.0   left      True      1.0   left     799.628411
# 31     red       13.0  right      True      0.0   left     997.721747
# 32     red      100.0  right      True      1.0  right    1123.158520
# 33     red        0.0  right      True      0.0   left     923.788757
# 34     red      100.0  right      True      1.0  right    1174.039620
# 35   green       13.0   left      True      1.0   left    1231.122599
# 36     red       35.0   left      True      1.0   left     789.501538
# 37   green        0.0   left      True      0.0  right    1083.748515
# 38   green        0.0  right     False      NaN    NaN    1707.403969
# 39   green       13.0   left      True      0.0  right    1010.329641
# 40   green       13.0  right      True      1.0  right    1361.685597
# 41     red       13.0  right     False      NaN    NaN    1667.456716
# 42     red       13.0  right      True      0.0   left     852.843012
# 43     red        0.0   left      True      1.0   left     837.441304
# 44     red       35.0   left      True      1.0   left     714.048974
# 45   green       35.0   left      True      1.0   left     759.585535
# 46   green      100.0   left      True      1.0   left     764.791706
# 47   green      100.0   left      True      1.0   left     744.467230
# 48     red       35.0  right      True      0.0   left    1212.328728
# 49     red        0.0  right      True      1.0  right     995.448842
# 50   green        0.0   left      True      0.0  right     988.022160
# 51     red        0.0   left      True      1.0   left     821.397292
# 52     red      100.0   left      True      1.0   left     749.779721
# 53     red      100.0  right      True      1.0  right    1151.859836
# 54   green       35.0   left      True      1.0   left     771.367774
# 55   green       35.0  right      True      1.0  right    1055.388067
# 56     red       13.0   left      True      1.0   left     802.036596
# 57   green       13.0   left      True      0.0  right    1118.388418
# 58   green      100.0   left      True      1.0   left     692.056535
# 59   green       35.0   left      True      1.0   left     730.962970
# 60     red       13.0   left      True      1.0   left     815.573535
# 61   green        0.0   left      True      0.0  right     798.855985
# 62   green      100.0  right      True      1.0  right    1094.035760
# 63     red      100.0   left      True      1.0   left     742.157720
# 64     red       35.0  right      True      1.0  right    1011.044966
# 65     red       13.0   left      True      0.0  right    1089.836955
# 66     red       35.0   left      True      1.0   left     631.228812
# 67     red        0.0  right      True      0.0   left     837.783323
# 68   green        0.0  right      True      1.0  right     784.657242
# 69     red       35.0  right      True      1.0  right    1032.475065
# 70   green       13.0   left      True      0.0  right     951.192864
# 71     red      100.0  right      True      0.0   left    1019.541571
# 72   green        0.0   left      True      0.0  right    1106.982531
# 73   green        0.0   left      True      1.0   left     880.269573
# 74     red        0.0  right      True      0.0   left     756.567873
# 75     red        0.0   left      True      0.0  right    1058.562697
# 76   green       13.0  right      True      0.0   left     854.788351
# 77   green       35.0   left      True      1.0   left     983.500149
# 78     red      100.0   left      True      1.0   left     703.951371
# 79     red        0.0   left      True      0.0  right    1276.422336
# 80   green       35.0  right      True      0.0   left    1086.529260
# 81   green      100.0   left      True      1.0   left     728.033982
# 82     red       35.0  right      True      0.0   left    1525.777780
# 83   green      100.0   left      True      1.0   left     862.826478
# 84   green      100.0   left      True      1.0   left     790.184240
# 85   green       13.0   left      True      0.0  right    1146.578600
# 86   green        0.0   left      True      1.0   left    1144.934510
# 87     red      100.0  right      True      1.0  right     936.107438
# 88     red       13.0  right      True      1.0  right    1125.680864
# 89     red       13.0  right      True      1.0  right    1403.537806
# 90   green       13.0   left      True      0.0  right     846.855826
# 91     red       13.0   left      True      1.0   left    1196.029189
# 92   green       35.0   left      True      1.0   left     948.910758
# 93     red       35.0   left      True      1.0   left     786.984276
# 94   green      100.0  right      True      1.0  right     892.415039
# 95     red      100.0   left      True      1.0   left     681.654842
# 96   green       35.0   left      True      0.0  right     855.116129
# 97   green       13.0  right      True      1.0  right    1056.781463
# 98   green       35.0   left      True      0.0  right    1102.365252
# 99   green       35.0   left      True      1.0   left     731.066449
# 100  green        0.0   left      True      1.0   left    1222.530647
# 101    red       13.0  right      True      0.0   left     995.622296
# 102    red       35.0   left      True      1.0   left    1071.362412
# 103  green      100.0   left      True      1.0   left     706.636261
# 104    red      100.0   left      True      1.0   left     576.880598
# 105    red      100.0  right      True      1.0  right     965.779977
# 106  green      100.0   left      True      1.0   left     773.447958
# 107    red      100.0  right      True      1.0  right     557.341626
# 108  green        0.0  right      True      1.0  right     864.386390
# 109    red       35.0   left      True      1.0   left     548.204234
# 110  green       35.0   left      True      0.0  right     504.120059
# 111  green       35.0  right      True      1.0  right     824.996913
# 112  green      100.0   left      True      1.0   left     714.331407
# 113    red        0.0   left      True      0.0  right     726.936059
# 114    red       13.0   left      True      0.0  right    1132.800160
# 115  green       13.0   left      True      0.0  right    1314.804930
# 116    red        0.0   left      True      1.0   left     815.818776
# 117  green       13.0   left      True      1.0   left    1053.973073
# 118  green        0.0   left      True      1.0   left     714.196087
# 119    red        0.0  right      True      0.0   left    1182.417863
# 120    red       13.0  right      True      1.0  right     862.654866
# 121  green       13.0   left      True      0.0  right     758.941764
# 122  green        0.0   left      True      0.0  right     835.386822
# 123    red        0.0  right      True      1.0  right    1083.913778
# 124  green      100.0  right      True      1.0  right     804.878811
# 125    red       13.0   left      True      0.0  right     817.758672
# 126    red       35.0  right      True      1.0  right     760.051721
# 127    red       35.0  right      True      1.0  right     736.097779
# 128    red      100.0   left      True      0.0  right    1002.919460
# 129    red       35.0  right      True      1.0  right    1072.846672
# 130  green      100.0   left      True      0.0  right     914.085133
# 131    red      100.0   left      True      0.0  right     811.293030
# 132  green       35.0   left      True      1.0   left     926.949553
# 133  green        0.0   left      True      1.0   left     951.029283
# 134  green      100.0   left      True      1.0   left    1055.150284
# 135    red       35.0   left      True      1.0   left    1161.332602
# 136  green       13.0   left      True      1.0   left    1228.613275
# 137  green        0.0   left      True      1.0   left     805.339870
# 138    red       13.0  right      True      0.0   left     948.062982
# 139  green       35.0   left      True      1.0   left     920.213094
# 140  green        0.0   left      True      1.0   left     797.904923
# 141  green       13.0  right      True      0.0   left     935.528753
# 142  green      100.0  right      True      0.0   left     663.998912
# 143  green      100.0   left      True      0.0  right     803.969341
# 144    red        0.0  right     False      NaN    NaN      81.772222
# 145    red       13.0   left      True      1.0   left    1093.060884
# 146    red       13.0   left      True      1.0   left     965.037516
# 147    red        0.0   left      True      1.0   left     929.189516
# 148    red      100.0   left      True      0.0  right    1148.086381
# 149    red       35.0  right      True      0.0   left    1010.165572
# 150  green        0.0  right      True      0.0   left     996.840349
# 151  green       13.0   left      True      0.0  right     979.314106
# 152    red       35.0   left      True      0.0  right    1458.534399
# 153    red        0.0   left      True      1.0   left     920.164042
# 154    red      100.0  right      True      0.0   left     764.014885
# 155    red        0.0  right      True      0.0   left     900.245361
# 156  green       35.0  right      True      0.0   left     994.633951
# 157    red      100.0  right      True      1.0  right    1326.695990
# 158  green       13.0   left      True      1.0   left    1053.013682
# 159    red       13.0  right      True      0.0   left    1046.953323
# 160  green       35.0   left      True      1.0   left    1278.616137
# 161  green       13.0   left     False      NaN    NaN    1633.906646
# 162    red       13.0   left      True      0.0  right     981.329653
# 163    red        0.0   left      True      0.0  right    1036.572058
# 164  green       35.0   left      True      0.0  right    1158.283977
# 165  green      100.0   left      True      1.0   left     799.026187
# 166    red       35.0  right      True      0.0   left    1182.078756
# 167  green       13.0  right      True      1.0  right     927.626292
# 168  green      100.0  right      True      0.0   left     972.284912
# 169  green      100.0   left      True      0.0  right    1263.613087
# 170    red       13.0   left      True      1.0   left    1404.351905
# 171    red        0.0   left      True      1.0   left     912.777656
# 172    red       35.0   left      True      1.0   left     770.401681
# 173  green        0.0   left      True      1.0   left     845.974519
# 174  green      100.0   left      True      0.0  right    1111.658693
# 175    red      100.0   left      True      1.0   left    1114.236282
# 176    red      100.0  right      True      0.0   left     802.438263
# 177  green        0.0   left      True      0.0  right     918.703306
# 178    red       35.0  right      True      1.0  right    1366.115419
# 179    red       35.0   left      True      0.0  right    1052.921553
# 180  green       35.0  right      True      1.0  right     586.035138
# 181    red       13.0  right      True      0.0   left    1223.818382
# 182    red      100.0  right     False      NaN    NaN    1652.382628
# 183    nan        NaN    nan     False      NaN    NaN       0.000000
# 184    red        0.0  right     False      NaN    NaN    1680.027349
# 185    red       13.0  right      True      0.0   left     865.545036
# 186  green       13.0   left      True      0.0  right    1243.140564
# 187    red        0.0  right     False      NaN    NaN    1641.539098
# 188  green       35.0   left      True      0.0  right    1458.710646
# 189  green       35.0   left      True      1.0   left    1486.750123
# 190  green        0.0   left      True      1.0   left    1283.489694
# 191  green        0.0  right      True      0.0   left    1015.442368
# 192  green       13.0   left      True      1.0   left     956.993489
# 193    red      100.0   left      True      0.0  right    1634.263801
# 194    red        0.0   left      True      1.0   left     963.145808
# 195    red       13.0  right      True      0.0   left     958.397530
# 196    red       35.0  right      True      1.0  right    1283.737446
# 197    red       35.0  right      True      1.0  right     863.474621
# 198  green       35.0   left      True      0.0  right     828.128579
# 199  green       13.0   left      True      0.0  right     917.220046
# 200  green      100.0  right      True      0.0   left    1300.086209
# 201  green        0.0   left      True      1.0   left     875.212111
# 202  green       35.0   left      True      1.0   left    1175.546657
# 203    red       35.0   left      True      1.0   left    1210.190167
# 204  green       13.0   left      True      1.0   left    1007.184077
# 205  green        0.0   left      True      1.0   left     846.563354
# 206    red        0.0  right      True      0.0   left     798.749447
# 207    red      100.0   left      True      1.0   left     662.596885
# 208    red       13.0   left      True      0.0  right    1007.053625
# 209  green       35.0  right      True      0.0   left    1154.582826
# 210    red       35.0   left      True      0.0  right     701.205062
# 211    red      100.0  right      True      0.0   left    1165.040169
# 212  green        0.0  right      True      1.0  right     926.949920
# 213  green       13.0  right      True      1.0  right    1031.788240
# 214  green       35.0   left      True      0.0  right    1086.603358
# 215    red      100.0   left      True      1.0   left    1314.320968
# 216    red       13.0   left      True      1.0   left     952.445583
# 217  green      100.0   left      True      1.0   left    1341.053219
# 218  green       13.0   left      True      1.0   left    1015.676058
# 219  green      100.0   left      True      0.0  right    1045.576638
# 220    red       13.0  right      True      1.0  right    1302.188636
# 221  green      100.0   left      True      0.0  right    1001.710673
# 222    red        0.0  right      True      1.0  right     672.595085
# 223    red        0.0   left      True      1.0   left     946.853360
# 224    red      100.0  right      True      0.0   left    1279.157843
# 225  green        0.0   left      True      0.0  right    1265.894803
# 226  green        0.0   left      True      1.0   left    1457.375576
# 227    red      100.0   left      True      0.0  right    1203.476075
# 228    red       35.0   left      True      1.0   left    1185.678521
# 229    red       13.0  right      True      0.0   left     999.748866
# 230  green        0.0   left      True      0.0  right    1008.497098
# 231    red      100.0  right      True      0.0   left    1135.006474
# 232  green       35.0   left      True      1.0   left    1424.517186
# 233  green       13.0   left      True      1.0   left    1210.190207
# 234    red       13.0  right      True      0.0   left     990.993732
# 235    red       35.0  right      True      0.0   left     979.033121
# 236    red      100.0   left      True      1.0   left    1113.793392
# 237    red       35.0   left      True      1.0   left    1273.088145
# 238  green       13.0   left      True      1.0   left    1248.493292
# 239    red       35.0  right      True      0.0   left    1123.528710
# 240    red        0.0   left      True      1.0   left    1193.146243
# 241  green      100.0  right      True      0.0   left    1278.113305
# 242  green       35.0   left      True      0.0  right     835.356281
# 243  green      100.0   left      True      0.0  right    1157.958366
# 244    red       13.0   left      True      0.0  right    1461.556362
# 245  green      100.0   left      True      0.0  right    1242.474760
# 246  green       13.0   left      True      1.0   left    1369.278158
# 247    red        0.0  right      True      0.0   left    1193.974588
# 248  green        0.0  right      True      0.0   left    1475.124549
# 249  green        0.0   left      True      0.0  right    1468.371451
# 250    red      100.0  right     False      NaN    NaN    1665.060701
# 251  green       35.0   left      True      1.0   left    1349.177891
# 252    red       13.0   left      True      1.0   left    1351.146834
# 253  green       35.0  right      True      0.0   left    1392.568404
# 254  green      100.0   left      True      0.0  right    1077.666332
# 255    red        0.0   left      True      0.0  right    1170.151450
# 256  green       13.0  right      True      1.0  right    1397.163652
# 257    red        0.0  right      True      1.0  right    1115.011429
# 258  green        0.0   left      True      0.0  right    1144.494110
# 259  green       35.0   left      True      0.0  right    1417.748988
# 260  green        0.0   left      True      1.0   left    1182.924446
# 261    red        0.0  right      True      1.0  right    1194.292962
# 262  green      100.0   left      True      0.0  right    1022.422832
# 263  green       13.0   left      True      0.0  right     577.189402
# 264    red       13.0   left      True      1.0   left    1161.400575
# 265    red       13.0  right      True      0.0   left    1242.061635
# 266    red       35.0   left      True      0.0  right    1266.263116
# 267  green        0.0   left      True      0.0  right    1562.255960
# 268    red        0.0   left      True      1.0   left    1579.246498
# 269  green       35.0  right      True      1.0  right    1503.527914
# 270  green      100.0   left      True      0.0  right     953.735186
# 271    red        0.0   left      True      0.0  right    1138.048516
# 272  green       35.0   left      True      0.0  right     777.082305
# 273  green        0.0  right      True      1.0  right    1071.736637
# 274  green       13.0   left      True      0.0  right     890.537466
# 275  green       13.0  right      True      1.0  right    1408.404807
# 276    red       35.0   left      True      0.0  right     790.916925
# 277    red       13.0   left      True      0.0  right    1398.511887
# 278    red        0.0  right      True      0.0   left    1091.446389
# 279    red      100.0   left      True      1.0   left    1552.875106
# 280  green       13.0   left      True      1.0   left    1569.022061
# 281    red      100.0  right      True      1.0  right    1344.523848
# 282  green      100.0   left      True      0.0  right    1126.139090
# 283    red       35.0  right      True      1.0  right    1090.019904
# 284    red       13.0  right      True      1.0  right    1097.230331
# 285  green       35.0   left      True      0.0  right     804.223128
# 286    red      100.0   left      True      1.0   left    1355.728460
# 287  green      100.0  right      True      0.0   left    1527.789547
# 288    red      100.0  right      True      1.0  right    1095.155200
# 289    red       35.0  right      True      1.0  right    1104.959478
# 290  green      100.0   left      True      0.0  right    1125.549367
# 291  green        0.0   left      True      0.0  right    1397.129848
# 292    red        0.0  right      True      0.0   left    1341.596763
# 293    red       35.0   left      True      1.0   left    1083.728757
# 294  green       35.0   left      True      0.0  right    1282.912888
# 295    red      100.0   left      True      0.0  right    1531.641238
# 296  green       35.0   left     False      NaN    NaN    1690.923266
# 297    red      100.0   left      True      0.0  right    1071.930283
# 298    red       35.0   left     False      NaN    NaN    1702.923144
# 299    red       35.0  right      True      1.0  right    1143.544404
# 300    red        0.0   left      True      0.0  right    1066.332517
# 301  green       35.0  right      True      1.0  right    1491.868913
# 302  green       13.0   left      True      0.0  right    1080.203194
# 303  green        0.0   left      True      0.0  right     947.360361
# 304  green       13.0   left      True      0.0  right    1026.652173
# 305  green        0.0  right     False      NaN    NaN    1692.040962
# 306    red       35.0  right      True      0.0   left     783.178898
# 307  green        0.0   left      True      1.0   left    1559.369059
# 308  green       13.0   left      True      1.0   left    1041.339560
# 309    red       13.0  right      True      0.0   left    1352.940110
# 310  green      100.0   left      True      0.0  right    1249.425172
# 311    red       13.0   left      True      0.0  right    1352.928979
# 312  green       13.0  right      True      0.0   left    1164.858736
# 313    red       13.0   left      True      1.0   left    1234.161373
# 314    red       13.0  right      True      0.0   left    1536.983591
# 315    red      100.0  right      True      0.0   left     246.215726
# 316  green      100.0  right      True      0.0   left    1627.810938
# 317  green       35.0   left      True      1.0   left     913.163221
# 318    red        0.0   left      True      0.0  right     917.074228
# 319  green      100.0   left      True      1.0   left    1048.072303
# 320    red        0.0  right      True      1.0  right    1242.587056
# 321    red      100.0  right      True      1.0  right    1149.145509
# 322  green        0.0   left      True      0.0  right    1387.717148
# 323    red       13.0   left      True      0.0  right    1063.292076
# 324    red       35.0  right      True      0.0   left    1307.171097
# 325    red        0.0  right      True      1.0  right     928.895382
# 326    red       13.0  right      True      1.0  right     812.558144
# 327    red      100.0  right      True      1.0  right     701.877548
# 328    red       13.0  right      True      1.0  right     660.324514
# 329  green       35.0   left      True      1.0   left     714.094418
# 330    red        0.0   left      True      1.0   left     652.047103
# 331  green       35.0  right      True      1.0  right    1045.631285
# 332  green       35.0   left      True      0.0  right     937.819746
# 333    red       13.0   left      True      1.0   left     741.827280
# 334    red      100.0   left      True      0.0  right    1151.675996
# 335  green        0.0   left      True      1.0   left     796.126837
# 336  green      100.0   left      True      0.0  right    1120.438313
# 337  green       13.0   left      True      0.0  right    1106.468657
# 338    red        0.0   left      True      1.0   left    1022.812464
# 339    red       35.0   left      True      1.0   left     997.585161
# 340  green       35.0   left      True      1.0   left     843.608521
# 341    red      100.0  right      True      0.0   left     871.920625
# 342    red        0.0  right      True      0.0   left     769.106786
# 343  green      100.0   left      True      0.0  right    1076.194185
# 344  green      100.0  right      True      0.0   left     849.828095
# 345    red      100.0   left      True      0.0  right     980.599153
# 346  green       13.0  right      True      1.0  right    1145.170339
# 347  green        0.0  right      True      1.0  right     811.201422
# 348    red       35.0   left      True      0.0  right     771.641925
# 349  green       13.0   left      True      0.0  right    1239.407838
# 350  green       13.0   left      True      1.0   left     903.425185
# 351  green        0.0   left      True      1.0   left    1148.926532
# 352  green      100.0   left      True      1.0   left     901.531993
# 353    red       35.0  right      True      0.0   left     635.234544
# 354  green      100.0   left      True      0.0  right     996.849698
# 355    red      100.0  right      True      0.0   left    1103.118937
# 356    red      100.0   left      True      0.0  right     840.784358
# 357  green       35.0   left      True      0.0  right     738.952377
# 358  green      100.0   left      True      1.0   left     973.744889
# 359  green        0.0   left      True      1.0   left    1198.559103
# 360  green       13.0   left      True      1.0   left     964.813936
# 361    red       13.0   left      True      1.0   left    1002.888645
# 362  green      100.0  right      True      0.0   left     833.530778
# 363    red      100.0  right      True      1.0  right    1221.380745
# 364    red       35.0   left      True      0.0  right     872.183113
# 365    red        0.0   left      True      0.0  right     978.977191
# 366    red       35.0  right      True      1.0  right     665.821465
# 367  green        0.0  right      True      0.0   left    1043.394383
# 368    red       35.0  right     False      NaN    NaN    1653.275706
# 369  green        0.0   left      True      0.0  right    1017.022138
# 370  green       35.0   left      True      1.0   left    1119.085436
# 371  green       35.0   left      True      1.0   left    1054.169906
# 372    red        0.0  right      True      0.0   left     900.521906
# 373    red       13.0   left      True      0.0  right    1210.089947
# 374    red       35.0   left      True      0.0  right    1043.386057
# 375    red        0.0  right      True      1.0  right    1372.631304
# 376    red       13.0  right      True      1.0  right    1160.185128
# 377    red       13.0  right      True      1.0  right    1062.588065
# 378    red      100.0   left      True      0.0  right     881.048130
# 379    red        0.0   left      True      0.0  right     828.359099
# 380  green       13.0  right      True      1.0  right    1058.386526
# 381  green      100.0   left      True      0.0  right     920.350937
# 382  green        0.0   left      True      1.0   left    1054.621404
# 383  green       35.0  right      True      0.0   left     828.809997
# 384  green       13.0   left      True      0.0  right    1329.115313
# 385  green       13.0   left      True      1.0   left    1093.733123
# 386  green        0.0  right      True      0.0   left    1098.576720
# 387    red       35.0  right      True      0.0   left    1082.123351
# 388    red       35.0   left      True      1.0   left    1005.500438
# 389    red        0.0  right      True      0.0   left     983.833138
# 390  green       13.0  right      True      0.0   left     873.176632
# 391    red       13.0  right      True      1.0  right     940.507592
# 392    red       35.0   left      True      0.0  right     822.764097
# 393  green       35.0   left      True      0.0  right    1339.861559
# 394  green       13.0   left      True      1.0   left     848.432193
# 395    red        0.0   left      True      0.0  right    1084.236621
# 396  green        0.0   left      True      1.0   left     513.388265
# 397  green        0.0   left      True      1.0   left    1171.322641
# 398  green       13.0   left      True      1.0   left     844.011878
# 399  green      100.0   left      True      0.0  right    1133.537852
# 400    red      100.0   left      True      1.0   left     938.068336
# 401    red      100.0  right      True      0.0   left    1542.055949
# 402  green       35.0   left      True      0.0  right    1002.613723
# 403    red       13.0   left      True      0.0  right    1077.203012
# 404    red       13.0  right      True      1.0  right     704.133180
# 405    red       35.0  right      True      1.0  right    1532.767066
# 406  green      100.0  right      True      0.0   left    1063.881906
# 407  green       35.0  right      True      0.0   left    1119.391949
# 408  green       13.0   left      True      1.0   left     861.438598
# 409  green       35.0   left      True      1.0   left    1216.226662
# 410    red      100.0   left      True      1.0   left    1096.426969
# 411  green      100.0   left      True      0.0  right    1089.286754
# 412    red        0.0  right      True      1.0  right    1047.285013
# 413    red        0.0   left      True      0.0  right    1395.095360
# 414    red       13.0   left      True      1.0   left     880.978002
# 415  green      100.0   left      True      0.0  right    1120.109761
# 416    red      100.0  right      True      0.0   left    1199.654701
# 417  green        0.0   left      True      0.0  right     747.237628
# 418    red       13.0  right      True      0.0   left    1177.976770
# 419    red      100.0  right      True      0.0   left     831.553191
# 420  green      100.0   left      True      0.0  right    1042.905917
# 421    red       35.0  right      True      0.0   left    1001.094574
# 422    red       35.0   left      True      0.0  right    1040.926145
# 423  green      100.0  right      True      0.0   left    1176.754103
# 424    red      100.0   left      True      0.0  right    1138.328006
# 425  green      100.0   left      True      1.0   left    1377.095781
# 426    red       13.0   left      True      1.0   left     987.005053
# 427    red      100.0   left      True      1.0   left     698.293002
# 428    red       13.0  right      True      1.0  right    1447.589779
# 429  green       13.0   left      True      1.0   left    1146.009601
# 430  green       13.0   left      True      0.0  right     915.798991
# 431  green      100.0   left      True      1.0   left     702.268231
# 432  green       35.0   left      True      1.0   left     846.354149
# 433    red       35.0  right      True      0.0   left     873.502130
# 434    red        0.0   left      True      0.0  right     840.019771
# 435    red       13.0   left      True      1.0   left     830.060104
# 436    red        0.0  right      True      1.0  right    1018.129518
# 437  green       35.0   left      True      1.0   left     801.361174
# 438  green       13.0   left      True      1.0   left    1223.493710
# 439    red        0.0  right      True      1.0  right     823.009487
# 440    red       35.0   left      True      1.0   left     817.094598
# 441  green        0.0   left      True      0.0  right     838.689994
# 442  green       35.0   left      True      1.0   left    1077.494549
# 443    red        0.0   left      True      0.0  right     849.464904
# 444  green        0.0  right      True      1.0  right     981.758887
# 445    red      100.0  right      True      1.0  right     758.605355
# 446  green       13.0  right      True      1.0  right     891.389278
# 447  green        0.0   left      True      0.0  right     700.151293
# 448  green       35.0  right      True      1.0  right     762.101146
# 449  green        0.0   left      True      0.0  right    1196.241881
# 450    red       13.0   left      True      0.0  right    1056.970302
# 451  green       13.0  right      True      1.0  right     993.094757
# 452    red        0.0   left      True      0.0  right     928.232557
# 453    red       35.0   left      True      0.0  right     906.154275
# 454    red      100.0   left      True      1.0   left     778.568047
# 455  green        0.0   left      True      0.0  right    1317.863177
# 456    red      100.0  right      True      1.0  right    1016.704603
# 457    red       13.0  right      True      1.0  right     904.047845
# 458  green       13.0   left      True      0.0  right     889.293542
# 459  green        0.0  right      True      1.0  right     877.081333
# 460  green        0.0   left      True      0.0  right    1013.458693
# 461  green      100.0   left      True      1.0   left     783.589468
# 462    red      100.0   left      True      1.0   left     774.035178
# 463    red        0.0   left      True      0.0  right    1164.629656
# 464    red       35.0   left      True      1.0   left     999.823013
# 465  green        0.0   left      True      0.0  right     994.474279
# 466  green       35.0   left      True      1.0   left     782.036455
# 467  green       13.0   left      True      0.0  right    1215.040747
# 468    red        0.0  right      True      1.0  right     785.762416
# 469  green      100.0   left      True      1.0   left     856.195574
# 470    red      100.0  right      True      1.0  right     967.650480
# 471  green      100.0   left      True      1.0   left    1145.417125
# 472  green       13.0   left      True      0.0  right    1069.646106
# 473    red       35.0  right      True      1.0  right    1130.298309
# 474    red       13.0  right      True      1.0  right    1433.666586
# 475    red       13.0   left      True      0.0  right    1424.956043
# 476  green       35.0   left      True      0.0  right     840.832742
# 477  green      100.0  right      True      1.0  right     797.593590
# 478    red        0.0  right      True      0.0   left    1077.633378
# 479  green       35.0   left      True      0.0  right    1003.138373
# 480  green       35.0  right      True      1.0  right     919.231841
# 481    red       35.0  right      True      1.0  right    1217.537282
# 482    red      100.0  right      True      1.0  right    1129.249705
# 483  green       13.0  right      True      1.0  right    1197.808404
# 484  green       35.0   left      True      0.0  right     815.443481
# 485    red       13.0   left      True      0.0  right    1220.246259
# 486    red        0.0   left      True      1.0   left     842.851207
# 487  green       35.0   left      True      1.0   left     813.621866
# 488  green        0.0   left      True      0.0  right     940.995445
# 489  green        0.0   left      True      0.0  right     887.650462
# 490    red       35.0   left      True      0.0  right     897.073578
# 491  green      100.0  right      True      0.0   left    1069.347102
# 492  green      100.0   left      True      1.0   left     795.140759
# 493    red       35.0   left      True      1.0   left     848.522575
# 494    red      100.0   left      True      1.0   left     870.380116
# 495    red      100.0   left      True      1.0   left     676.906488
# 496  green      100.0   left      True      1.0   left     562.088084
# 497  green       13.0   left      True      1.0   left     994.932210
# 498  green      100.0   left      True      1.0   left     742.597811
# 499  green        0.0   left      True      1.0   left     904.471261
# 500  green       13.0   left      True      0.0  right     713.928247
# 501    red        0.0   left      True      0.0  right     687.662196
# 502    red       13.0  right      True      0.0   left    1136.895850
# 503    red       13.0   left      True      0.0  right    1014.985667
# 504  green       13.0   left      True      1.0   left     692.353659
# 505  green        0.0  right      True      0.0   left     672.147306
# 506    red       35.0  right      True      0.0   left     796.421104
# 507  green       35.0  right      True      1.0  right     791.087732
# 508    red       13.0  right      True      1.0  right     852.148582
# 509    red      100.0  right      True      1.0  right     692.874693
# 510    red        0.0  right      True      1.0  right     701.176564
# 511  green       35.0   left      True      0.0  right     993.420457
# 512    red       35.0  right      True      1.0  right     709.406700
# 513    red        0.0  right      True      1.0  right     730.717700
# 514    red       35.0  right      True      1.0  right     627.515858
# 515  green      100.0  right      True      1.0  right     739.553467
# 516  green       35.0   left      True      0.0  right     711.135564
# 517  green        0.0   left      True      0.0  right     678.177274
# 518  green       35.0   left      True      1.0   left     716.690208
# 519    red       35.0  right      True      0.0   left     649.664840
# 520    red      100.0  right      True      0.0   left     786.125432
# 521  green      100.0   left      True      0.0  right     862.435939
# 522    red      100.0   left      True      1.0   left     820.507772
# 523    red        0.0  right      True      0.0   left     789.201488
# 524  green       13.0   left      True      0.0  right     985.382959
# 525    red       35.0   left      True      0.0  right    1075.979374
# 526    red       13.0   left      True      0.0  right     725.079218
# 527    red        0.0   left      True      1.0   left     774.081871
# 528  green        0.0   left      True      1.0   left     801.863088
# 529  green      100.0   left      True      1.0   left     686.689627
# 530  green        0.0  right      True      0.0   left     812.110401
# 531    red        0.0  right      True      0.0   left    1122.341593
# 532  green       13.0   left      True      1.0   left    1435.742046
# 533    red       13.0  right      True      0.0   left     796.680018
# 534    red        0.0   left      True      0.0  right     876.686185
# 535    red       13.0   left      True      0.0  right     872.008657
# 536    red      100.0   left      True      0.0  right    1152.224061
# 537  green      100.0   left      True      0.0  right    1074.847111
# 538  green       35.0   left      True      1.0   left    1203.268187
# 539  green       13.0  right      True      0.0   left     928.415503
# 540  green       35.0  right      True      0.0   left     733.294996
# 541    red      100.0  right      True      1.0  right    1248.009518
# 542    red       13.0  right      True      1.0  right     918.278177
# 543    red       35.0   left      True      0.0  right     831.942705
# 544  green        0.0   left      True      0.0  right     745.949511
# 545  green       13.0   left      True      0.0  right    1126.369380
# 546  green        0.0   left      True      0.0  right    1495.154828
# 547  green       13.0   left      True      1.0   left    1118.681781
# 548    red        0.0  right      True      0.0   left    1167.019631
# 549  green       35.0   left      True      1.0   left     993.819414
# 550    red       13.0   left      True      1.0   left     844.948913
# 551  green        0.0   left      True      1.0   left    1062.802762
# 552  green      100.0  right      True      0.0   left     869.150685
# 553  green       13.0  right      True      1.0  right    1339.962656
# 554  green       35.0   left      True      0.0  right    1149.446995
# 555    red       35.0   left      True      0.0  right     743.262282
# 556  green      100.0   left      True      1.0   left    1183.926495
# 557  green      100.0   left      True      1.0   left     973.446047
# 558  green        0.0   left      True      1.0   left     971.980573
# 559  green        0.0  right      True      0.0   left     824.703595
# 560    red       13.0  right      True      1.0  right    1098.788019
# 561  green       13.0   left      True      0.0  right    1265.720841
# 562  green       35.0   left      True      0.0  right     531.997213
# 563  green       13.0   left      True      1.0   left    1006.479518
# 564    red        0.0   left      True      1.0   left     804.552824
# 565    red        0.0  right      True      0.0   left    1216.447527
# 566    red       35.0   left      True      0.0  right    1130.440518
# 567    red       13.0  right      True      1.0  right     953.463425
# 568    red        0.0   left      True      0.0  right     746.162195
# 569  green       35.0  right      True      1.0  right     895.051618
# 570    red       35.0  right      True      1.0  right     813.760884
# 571    red       13.0   left      True      0.0  right     782.968963
# 572    red      100.0  right      True      1.0  right     901.432083
# 573    red      100.0   left      True      1.0   left     984.337113
# 574    red      100.0   left      True      1.0   left    1514.348847
# 575  green      100.0   left      True      1.0   left     948.458565
# 576    red       35.0  right      True      1.0  right     844.497374
# 577    red      100.0  right      True      1.0  right     961.478738
# 578    red      100.0   left      True      0.0  right     953.682349
# 579    red       35.0   left      True      0.0  right    1052.922647
# 580    red       13.0   left      True      0.0  right     862.110343
# 581    red        0.0  right      True      0.0   left    1012.029010
# 582  green      100.0  right      True      0.0   left     725.137132
# 583  green      100.0   left     False      NaN    NaN    1629.136665
# 584    nan        NaN    nan     False      NaN    NaN       0.000000
# 585  green       35.0   left      True      0.0  right    1573.412925
# 586  green        0.0   left     False      NaN    NaN    1712.566303
# 587    red        0.0  right      True      0.0   left     801.896610
# 588  green        0.0   left     False      NaN    NaN    1634.905790
# 589    red       35.0  right      True      0.0   left     407.368855
# 590  green        0.0   left      True      0.0  right    1423.306948
# 591    red       13.0  right      True      1.0  right    1178.591788
# 592  green      100.0   left      True      0.0  right     812.159706
# 593    red      100.0  right      True      1.0  right     693.871260
# 594    red        0.0   left      True      0.0  right     853.025824
# 595  green       13.0   left      True      1.0   left     618.832274
# 596  green       35.0  right      True      0.0   left     849.331651
# 597    red       13.0   left      True      0.0  right     988.154474
# 598    red      100.0   left      True      1.0   left    1209.166222
# 599    red        0.0   left      True      1.0   left    1210.496637
# 600  green        0.0  right      True      0.0   left     908.322741
# 601    red      100.0  right      True      0.0   left     683.588043
# 602    red       35.0   left      True      1.0   left    1333.730410
# 603  green       13.0   left      True      0.0  right     710.973586
# 604  green       13.0   left      True      0.0  right     686.055089
# 605  green       35.0   left      True      0.0  right    1151.073982
# 606  green       35.0   left      True      0.0  right    1230.754973
# 607    red       35.0  right      True      1.0  right    1049.309345
# 608  green      100.0   left      True      0.0  right     908.539778
# 609    red       13.0  right      True      0.0   left     572.343738
# 610  green       13.0  right      True      1.0  right    1408.166518
# 611  green      100.0  right      True      1.0  right     990.071940
# 612    red       13.0   left      True      0.0  right     965.171178
# 613    red       13.0  right      True      1.0  right     869.662239
# 614  green        0.0   left      True      0.0  right    1120.316341
# 615  green       13.0   left      True      1.0   left     741.666471
# 616  green       35.0   left      True      1.0   left    1494.770667
# 617    red       35.0  right      True      1.0  right    1167.462557
# 618  green       35.0   left      True      0.0  right    1122.023004
# 619    red      100.0  right      True      1.0  right     810.616721
# 620  green      100.0   left      True      0.0  right    1131.588597
# 621    red      100.0   left      True      0.0  right     745.905169
# 622  green       35.0  right      True      0.0   left     794.317473
# 623  green       13.0   left      True      0.0  right    1133.185825
# 624    red      100.0  right      True      1.0  right     920.771527
# 625  green        0.0   left      True      0.0  right    1202.632013
# 626  green      100.0   left      True      1.0   left    1169.891072
# 627  green        0.0  right      True      1.0  right     944.020900
# 628    red       35.0  right      True      1.0  right     915.652882
# 629  green       13.0   left      True      0.0  right     900.854987
# 630  green       13.0  right      True      1.0  right     946.810401
# 631    red        0.0   left      True      1.0   left    1369.912726
# 632    red       35.0   left      True      1.0   left    1059.581809
# 633    red       35.0   left      True      1.0   left     799.922024
# 634  green       35.0   left      True      1.0   left     893.467965
# 635  green      100.0   left      True      1.0   left     803.384172
# 636    red      100.0   left      True      1.0   left     622.089011
# 637    red       13.0  right      True      0.0   left     784.430111
# 638    red       13.0   left      True      1.0   left     969.987859
# 639    red        0.0  right      True      0.0   left     760.318593
# 640  green        0.0   left      True      0.0  right     942.903041
# 641    red        0.0  right      True      0.0   left     906.231471
# 642    red        0.0   left      True      1.0   left     839.479397

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import hdf5storage

def process_practice_sessions(folders, raw_dir, should_save=False, session_type= 'practice'):

	for idx, folder in enumerate(folders):
		trial_path = folder / session_type
		files = sorted(trial_path.glob('*.mat'))

		if not files:
			# print(f"No .mat files found in {trial_path}")
			continue

		session_data = {"event": [], "time": []}

		# Load and concatenate data
		for file in files:
			temp_data = hdf5storage.loadmat(file.as_posix())
			if temp_data['event'].shape[0] > 5:
				session_data["event"].append(temp_data['event'])
				session_data["time"].append(temp_data['time'])

		session_data["event"] = np.concatenate(session_data["event"])
		session_data["time"] = np.concatenate(session_data["time"])

		# Create DataFrame
		event = session_data['event']
		df = pd.DataFrame({
			'color': np.select([event[:, 4] == 6101, event[:, 4] == 6102], ['green', 'red'], default=np.NaN),
			'coherence': np.select(
				[event[:, 3] == 4100, event[:, 3] == 4101, event[:, 3] == 4102, event[:, 3] == 4103],
				[100, 35, 13, 0],
				default=np.NaN
			),
			'target': np.select([event[:, 2] == 4000, event[:, 2] == 4001], ['left', 'right'], default=np.NaN),
		})

		# Mark invalid trials
		invalid_trials = np.where(
			(event[:, 8] == 5007) | (event[:, 7] == 5005) | (event[:, 7] == 0) | (event[:, 7] == 5008)
		)[0]
		df['is_valid'] = True
		df.loc[invalid_trials, 'is_valid'] = False

		# Determine outcome
		df['outcome'] = np.nan
		df.loc[np.where(event[:, 8] == 5510)[0], 'outcome'] = 1
		df.loc[np.where(event[:, 7] == 5006)[0], 'outcome'] = 0

		# Determine choice
		df['choice'] = df.apply(determine_choice, axis=1)

		# Calculate reaction time
		df['reaction_time'] = session_data['time'][:, 7] - session_data['time'][:, 6]

		# Infer prior condition
		prior, _, _ = get_prior_condition(df)

		return df

# %%
fragment_data_path = raw_dir / 'harvard_data' / 'pd'
# fragment_data_path = raw_dir / 'harvard_data' / 'hc'
assert fragment_data_path.exists(), f"Fragment data path {fragment_data_path} does not exist."

session_type = 'trial'

# Get folder names
folders = [f for f in fragment_data_path.iterdir() if f.is_dir()]

for idx, folder in enumerate(sorted(folders)):
	df  = process_practice_sessions([folder], raw_dir, session_type=session_type, should_save=False)
	if df is not None:
		# print(f"Processed folder {folder.name} with {len(df)} trials.")
		overall_accuracy = df['outcome'].sum() / len(df) * 100
		valid_accuracy = df[df.is_valid]['outcome'].mean() * 100
		accu_on_100 = df[(df.is_valid) & (df['coherence'] == 100)]['outcome'].mean() * 100

		print(f"Subject: {folder.name}, Valid Trials: {df.is_valid.sum()} / {len(df)}, 100% coherence Accuracy Rate: {accu_on_100:.2f}%,  Overall Accuracy: {overall_accuracy:.2f}%")
# Out:
# Subject: P25_off, Valid Trials: 161 / 824, 100% coherence Accuracy Rate: 63.51%,  Overall Accuracy: 10.68%
# Subject: P25_on, Valid Trials: 242 / 724, 100% coherence Accuracy Rate: 54.55%,  Overall Accuracy: 16.44%
# Subject: P26_off, Valid Trials: 605 / 733, 100% coherence Accuracy Rate: 49.02%,  Overall Accuracy: 44.20%
# Subject: P26_on, Valid Trials: 626 / 651, 100% coherence Accuracy Rate: 53.90%,  Overall Accuracy: 53.92%
# Subject: P27_off, Valid Trials: 621 / 646, 100% coherence Accuracy Rate: 33.12%,  Overall Accuracy: 42.72%
# Subject: P27_on, Valid Trials: 623 / 643, 100% coherence Accuracy Rate: 56.05%,  Overall Accuracy: 50.08%

# %%
from scipy.io import loadmat
def extract_creation_date(mat_header):
    """Extract creation date from MATLAB .mat file header."""
    header_str = mat_header.decode('utf-8') if isinstance(mat_header, bytes) else mat_header
    if 'Created on:' in header_str:
        creation_info = header_str.split('Created on:')[1].strip()
        return creation_info
    else:
        return "Creation date not found."

def load_mat_file(file_path):
	try:
		data = loadmat(file_path, squeeze_me=True, struct_as_record=False)
		return extract_creation_date(data['__header__'])
	except Exception as e:
		print(f"Error loading {file_path}: {e}")
		return None
# Out:
# Metadata for /mnt/pd-data/raw/harvard_data/pd/P2_off/practice: 250318_095525.mat, Creation Date: Mon Apr 28 08:48:23 2025
# Metadata for /mnt/pd-data/raw/harvard_data/pd/P2_off/practice: 250318_095103.mat, Creation Date: Tue Mar 18 09:55:51 2025
# Metadata for /mnt/pd-data/raw/harvard_data/pd/P2_off/practice: 250318_095304.mat, Creation Date: Fri Feb 28 09:31:21 2025
# Metadata for /mnt/pd-data/raw/harvard_data/pd/P2_off/trial: 250318_095718.mat, Creation Date: Tue Mar 18 10:06:36 2025
# Metadata for /mnt/pd-data/raw/harvard_data/pd/P2_off/trial: 250318_101912.mat, Creation Date: Tue Mar 18 10:29:43 2025
# Metadata for /mnt/pd-data/raw/harvard_data/pd/P2_off/trial: 250318_103057.mat, Creation Date: Tue Mar 18 10:40:11 2025
# Metadata for /mnt/pd-data/raw/harvard_data/pd/P2_off/trial: 250318_100850.mat, Creation Date: Tue Mar 18 10:18:15 2025

# %%
import datetime
from scipy.io import loadmat  # Make sure this import is available

def extract_length_from_mat(filepath):
	"""Extracts data length from a MATLAB .mat file."""
	data = loadmat(filepath)
	# Exclude meta-entries (those starting with '__')
	for key in data:
		if not key.startswith("__"):
			try:
				return len(data[key])
			except TypeError:
				continue
	return "N/A"

for folder_name in ['P8_on', 'P8_off', 'P2_on', 'P2_off', 'P5_on', 'P5_off']:
	base_dir = raw_dir / 'harvard_data' / 'pd' / folder_name
	files = sorted(list(base_dir.rglob('*.mat')))

	def get_filename_timestamp(filename):
		return datetime.datetime.strptime(filename.split(".")[0], "%y%m%d_%H%M%S")

	def get_time_difference(filename_time, creation_time_str):
		creation_time = datetime.datetime.strptime(creation_time_str, "%a %b %d %H:%M:%S %Y")
		return creation_time - filename_time

	print("-" * 120)
	print(f"Processing folder: {folder_name}")
	print("-" * 120)
	print(f"{'Folder':<25} {'Length':<8} {'Filename':<30} {'Creation Date':<25} {'Time Difference'}")
	print("-" * 120)

	files = sorted(files, key=lambda x: x.name)
	for file in files:
		creation_date = load_mat_file(file.as_posix())  # Assumes this extracts the 'Created on' date
		filename_time = get_filename_timestamp(file.name)
		time_diff = get_time_difference(filename_time, creation_date)
		data_length = extract_length_from_mat(file.as_posix())

		print(f"{str(file.parent.name):<25} {str(data_length):<8} {file.name:<30} {creation_date:<25} {time_diff}")
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Processing folder: P8_on
# ------------------------------------------------------------------------------------------------------------------------
# Folder                    Length   Filename                       Creation Date             Time Difference
# ------------------------------------------------------------------------------------------------------------------------
# practice                  52       250314_121809.mat              Mon Apr 28 10:11:20 2025  44 days, 21:53:11
# practice                  53       250314_121934.mat              Fri Mar 14 12:22:27 2025  0:02:53
# practice                  54       250314_122015.mat              Mon Apr 28 10:15:21 2025  44 days, 21:55:06
# practice                  53       250314_122212.mat              Fri Mar 14 12:22:27 2025  0:00:15
# trial                     161      250314_122343.mat              Fri Mar 14 12:30:43 2025  0:07:00
# trial                     161      250314_123121.mat              Fri Mar 14 12:39:11 2025  0:07:50
# trial                     160      250314_124007.mat              Fri Mar 14 12:47:26 2025  0:07:19
# trial                     161      250314_124859.mat              Fri Mar 14 12:56:18 2025  0:07:19
# ------------------------------------------------------------------------------------------------------------------------
# Processing folder: P8_off
# ------------------------------------------------------------------------------------------------------------------------
# Folder                    Length   Filename                       Creation Date             Time Difference
# ------------------------------------------------------------------------------------------------------------------------
# practice                  50       250325_065440.mat              Mon Apr 28 11:19:44 2025  34 days, 4:25:04
# practice                  50       250325_065738.mat              Mon Apr 28 11:22:37 2025  34 days, 4:24:59
# trial                     161      250325_065906.mat              Tue Mar 25 07:06:47 2025  0:07:41
# trial                     162      250325_070741.mat              Tue Mar 25 07:15:05 2025  0:07:24
# trial                     160      250325_071548.mat              Tue Mar 25 07:23:08 2025  0:07:20
# trial                     163      250325_072346.mat              Tue Mar 25 07:30:57 2025  0:07:11
# ------------------------------------------------------------------------------------------------------------------------
# Processing folder: P2_on
# ------------------------------------------------------------------------------------------------------------------------
# Folder                    Length   Filename                       Creation Date             Time Difference
# ------------------------------------------------------------------------------------------------------------------------
# practice                  52       250325_100753.mat              Mon Apr 28 11:30:25 2025  34 days, 1:22:32
# practice                  54       250325_100951.mat              Mon Apr 28 11:33:10 2025  34 days, 1:23:19
# trial                     187      250325_101214.mat              Tue Mar 25 10:21:54 2025  0:09:40
# trial                     186      250325_103157.mat              Tue Mar 25 10:41:03 2025  0:09:06
# trial                     171      250325_104225.mat              Tue Mar 25 10:51:16 2025  0:08:51
# trial                     180      250325_105238.mat              Tue Mar 25 11:01:58 2025  0:09:20
# ------------------------------------------------------------------------------------------------------------------------
# Processing folder: P2_off
# ------------------------------------------------------------------------------------------------------------------------
# Folder                    Length   Filename                       Creation Date             Time Difference
# ------------------------------------------------------------------------------------------------------------------------
# practice                  64       250318_095103.mat              Tue Mar 18 09:55:51 2025  0:04:48
# practice                  51       250318_095304.mat              Fri Feb 28 09:31:21 2025  -19 days, 23:38:17
# practice                  50       250318_095525.mat              Mon Apr 28 08:48:23 2025  40 days, 22:52:58
# trial                     211      250318_095718.mat              Tue Mar 18 10:06:36 2025  0:09:18
# trial                     213      250318_100850.mat              Tue Mar 18 10:18:15 2025  0:09:25
# trial                     215      250318_101912.mat              Tue Mar 18 10:29:43 2025  0:10:31
# trial                     185      250318_103057.mat              Tue Mar 18 10:40:11 2025  0:09:14
# ------------------------------------------------------------------------------------------------------------------------
# Processing folder: P5_on
# ------------------------------------------------------------------------------------------------------------------------
# Folder                    Length   Filename                       Creation Date             Time Difference
# ------------------------------------------------------------------------------------------------------------------------
# practice                  55       250415_063733.mat              Mon Apr 28 10:59:44 2025  13 days, 4:22:11
# practice                  50       250415_063849.mat              Mon Apr 28 11:04:04 2025  13 days, 4:25:15
# practice                  2        250415_063902.mat              Mon Apr 28 11:04:49 2025  13 days, 4:25:47
# trial                     165      250415_064557.mat              Tue Apr 15 07:00:35 2025  0:14:38
# trial                     163      250415_070124.mat              Tue Apr 15 07:08:24 2025  0:07:00
# trial                     162      250415_070856.mat              Tue Apr 15 07:15:53 2025  0:06:57
# trial                     161      250415_071638.mat              Tue Apr 15 07:23:39 2025  0:07:01
# practice                  50       250428_064118.mat              Mon Apr 28 11:07:53 2025  4:26:35
# ------------------------------------------------------------------------------------------------------------------------
# Processing folder: P5_off
# ------------------------------------------------------------------------------------------------------------------------
# Folder                    Length   Filename                       Creation Date             Time Difference
# ------------------------------------------------------------------------------------------------------------------------
# practice                  51       250401_065543.mat              Tue Apr  1 07:00:55 2025  0:05:12
# practice                  50       250401_065823.mat              Mon Apr 28 08:48:23 2025  27 days, 1:50:00
# practice                  51       250401_070015.mat              Mon Apr 28 10:24:01 2025  27 days, 3:23:46
# trial                     171      250401_070206.mat              Tue Apr  1 07:09:33 2025  0:07:27
# trial                     199      250401_071004.mat              Tue Apr  1 07:17:33 2025  0:07:29
# trial                     193      250401_071814.mat              Tue Apr  1 07:25:18 2025  0:07:04
# trial                     170      250401_072607.mat              Tue Apr  1 07:33:04 2025  0:06:57

# %%
import datetime
from scipy.io import loadmat

def extract_length_from_mat(filepath):
	data = loadmat(filepath)
	for key in data:
		if not key.startswith("__"):
			try:
				return len(data[key])
			except TypeError:
				continue
	return "N/A"

def get_filename_timestamp(filename):
	return datetime.datetime.strptime(filename.split(".")[0], "%y%m%d_%H%M%S")

# Get yesterday's date
yesterday = datetime.date.today() - datetime.timedelta(days=1)

# Collect data
entries = []
base_dir = raw_dir / 'harvard_data' / 'pd'
files = list(base_dir.rglob('*.mat'))

for file in files:
	creation_str = load_mat_file(file.as_posix())  # e.g., "Tue Apr 23 10:06:36 2025"
	creation_dt = datetime.datetime.strptime(creation_str, "%a %b %d %H:%M:%S %Y")

	if creation_dt.date() == yesterday:
		data_length = extract_length_from_mat(file.as_posix())
		entries.append((
			file.parent.parent.name,  # Parent folder (e.g., P8_off)
			file.parent.name,         # Subfolder (e.g., trial)
			data_length,
			file.name,
			creation_str,
			creation_dt
		))

# Sort by creation datetime
entries.sort(key=lambda x: x[5])  # Sort by creation_dt

# Print header
print("-" * 130)
print(f"{'Parent Folder':<20} {'Subfolder':<20} {'Length':<8} {'Filename':<30} {'Creation Date':<25}")
print("-" * 130)

# Print sorted entries
for parent, subfolder, length, filename, creation_str, _ in entries:
	print(f"{parent:<20} {subfolder:<20} {str(length):<8} {filename:<30} {creation_str:<25}")
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------
# Parent Folder        Subfolder            Length   Filename                       Creation Date
# ----------------------------------------------------------------------------------------------------------------------------------
# P5_off               practice             50       250401_065823.mat              Mon Apr 28 08:48:23 2025
# P2_off               practice             50       250318_095525.mat              Mon Apr 28 08:48:23 2025
# P8_on                practice             52       250314_121809.mat              Mon Apr 28 10:11:20 2025
# P8_on                practice             54       250314_122015.mat              Mon Apr 28 10:15:21 2025
# P5_off               practice             51       250401_070015.mat              Mon Apr 28 10:24:01 2025
# P5_on                practice             55       250415_063733.mat              Mon Apr 28 10:59:44 2025
# P5_on                practice             50       250415_063849.mat              Mon Apr 28 11:04:04 2025
# P5_on                practice             2        250415_063902.mat              Mon Apr 28 11:04:49 2025
# P5_on                practice             50       250428_064118.mat              Mon Apr 28 11:07:53 2025
# P8_off               practice             50       250325_065440.mat              Mon Apr 28 11:19:44 2025
# P8_off               practice             50       250325_065738.mat              Mon Apr 28 11:22:37 2025
# P2_on                practice             52       250325_100753.mat              Mon Apr 28 11:30:25 2025
# P2_on                practice             54       250325_100951.mat              Mon Apr 28 11:33:10 2025

# %%
dir = raw_dir / 'harvard_data' / 'pd'

data = load_mat_file(dir / 'P8_on' / 'practice' / '250314_121934.mat')
data2 = load_mat_file(dir / 'P8_on' / 'practice' / '250314_122212.mat')

print(f"P8_on practice 250314_121934 and 250314_122212 are same: {data == data2}")


data = load_mat_file(dir / 'P5_off' / 'practice' / '250401_065823.mat')
data2 = load_mat_file(dir / 'P2_off' / 'practice' / '250318_095525.mat')

print(f"P5_off practice 250401_065823 and p2_off 250318_095525 are same: {data == data2}")
# Out:
# P8_on practice 250314_121934 and 250314_122212 are same: True
# P5_off practice 250401_065823 and p2_off 250318_095525 are same: True

# %% [markdown]
# 50 trials in 13 secs P5_on
# Yesterday's date in p5_on
